# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Brennan Darvey O. Espinosa

# %% [markdown]
# source: https://www.kaggle.com/datasets/mylesoneill/game-of-thrones?resource=download&select=battles.csv

# %% [markdown]
# <h1>CREATE DATA</h1>

# %%
got = pd.DataFrame({
    'Year':[
        298,
        298,
        298,
        298,
        298
    ],
    'battle_number':[
        1,
        2,
        3,
        4,
        5,
    ],
    'attacker_king':[
        "Joffrey/Tommen Baratheon",
        "Joffrey/Tommen Baratheon",
        "Joffrey/Tommen Baratheon",
        "Rob Stark",
        "Rob Stark"
    ],
    'defender_king':[
        "Rob Stark",
        "Rob Stark",
        "Rob Stark",
        "Joffrey/Tommen Baratheon",
        "Joffrey/Tommen Baratheon",    
    ],
    'attacker_1':[
        "Lannister",
        "Lannister",
        "Lannister",
        "Stark",
        "Stark",
    ],
    'attacker_2':[
        "",
        "",
        "",
        "",
        "Tully",
    ],
    'attacker_3':[
        "",
        "",
        "",
        "",
        "",
    ],
    'attacker_4':[
        "",
        "",
        "",
        "",
        "",
    ],
    'defender_1':[
        "Tully",
        "Baratheon",
        "Tully",
        "Lannister",
        "Lannister",
    ],
}, columns=['Year','battle_number','attacker_king','defender_king','attacker_1','attacker_2','attacker_3','attacker_4','defender_1',])

# %% [markdown]
# <h1>Read Data</h1>

# %%
got
# Out:
#    Year  battle_number             attacker_king             defender_king  \
# 0   298              1  Joffrey/Tommen Baratheon                 Rob Stark
# 1   298              2  Joffrey/Tommen Baratheon                 Rob Stark
# 2   298              3  Joffrey/Tommen Baratheon                 Rob Stark
# 3   298              4                 Rob Stark  Joffrey/Tommen Baratheon
# 4   298              5                 Rob Stark  Joffrey/Tommen Baratheon
#
#   attacker_1 attacker_2 attacker_3 attacker_4 defender_1
# 0  Lannister                                       Tully
# 1  Lannister                                   Baratheon
# 2  Lannister                                       Tully
# 3      Stark                                   Lannister
# 4      Stark      Tully                        Lannister

# %%
got.index = [
    "Battle of the Golden Tooth",
    "Battle at the Mummer's Ford",
    "Battle of Riverrun",
    "Battle of the Green Fork",
    "Battle of the Whispering Wood"
]

# %%
got
# Out:
#                                Year  battle_number             attacker_king  \
# Battle of the Golden Tooth      298              1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford     298              2  Joffrey/Tommen Baratheon
# Battle of Riverrun              298              3  Joffrey/Tommen Baratheon
# Battle of the Green Fork        298              4                 Rob Stark
# Battle of the Whispering Wood   298              5                 Rob Stark
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon      Stark      Tully
#
#                               attacker_3 attacker_4 defender_1
# ...

# %%
got.size
# Out:
# 45

# %%
got.index
# Out:
# Index(['Battle of the Golden Tooth', 'Battle at the Mummer's Ford',
#        'Battle of Riverrun', 'Battle of the Green Fork',
#        'Battle of the Whispering Wood'],
#       dtype='object')

# %% [markdown]
# <h1>Update Data<h1>

# %%
new_data = pd.Series({
    'Year': 298,
    'battle_number': 6,
    'defender_king': 'Joffrey/Tommen Baratheon',
    'attacker_1': 'Stark',
    'attacker_2': 'Tully',
    'attacker_3': '',
    'attacker_4': '',
    'defender_1': 'Lannister',
}, name='Battle of the Camps')

# %%
got = pd.concat([got, new_data.to_frame().T], ignore_index=False)

# %%
got
# Out:
#                               Year battle_number             attacker_king  \
# Battle of the Golden Tooth     298             1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford    298             2  Joffrey/Tommen Baratheon
# Battle of Riverrun             298             3  Joffrey/Tommen Baratheon
# Battle of the Green Fork       298             4                 Rob Stark
# Battle of the Whispering Wood  298             5                 Rob Stark
# Battle of the Camps            298             6                       NaN
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon      Stark      Tully
# ...

# %%
got_filled = got.fillna('Unknown')

# %%
got
# Out:
#   Year battle_number             attacker_king             defender_king  \
# 0  298             1  Joffrey/Tommen Baratheon                 Rob Stark
# 1  298             2  Joffrey/Tommen Baratheon                 Rob Stark
# 2  298             3  Joffrey/Tommen Baratheon                 Rob Stark
# 3  298             4                 Rob Stark  Joffrey/Tommen Baratheon
# 4  298             5                 Rob Stark  Joffrey/Tommen Baratheon
# 5  298             6                       NaN  Joffrey/Tommen Baratheon
#
#   attacker_1 attacker_2 attacker_3 attacker_4 defender_1
# 0  Lannister                                       Tully
# 1  Lannister                                   Baratheon
# 2  Lannister                                       Tully
# 3      Stark                                   Lannister
# 4      Stark      Tully                        Lannister
# 5      Stark      Tully                        Lannister

# %%
got.loc["Battle of the Camps", 'attacker_king'] = "Robb Stark"

# %% [markdown]
# <h1>Delete</h1>

# %%
got
# Out:
#                               Year battle_number             attacker_king  \
# Battle of the Golden Tooth     298             1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford    298             2  Joffrey/Tommen Baratheon
# Battle of Riverrun             298             3  Joffrey/Tommen Baratheon
# Battle of the Green Fork       298             4                 Rob Stark
# Battle of the Whispering Wood  298             5                 Rob Stark
# Battle of the Camps            298             6                Robb Stark
# 5                              NaN           NaN                Robb Stark
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# ...

# %%
got.loc[5, 'attacker_king'] = np.nan

# %%
got
# Out:
#                               Year battle_number             attacker_king  \
# Battle of the Golden Tooth     298             1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford    298             2  Joffrey/Tommen Baratheon
# Battle of Riverrun             298             3  Joffrey/Tommen Baratheon
# Battle of the Green Fork       298             4                 Rob Stark
# Battle of the Whispering Wood  298             5                 Rob Stark
# Battle of the Camps            298             6                Robb Stark
# 5                              NaN           NaN                       NaN
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# ...

# %%
got = got.rename(index={5: 'ERROR'})

# %%
got
# Out:
#                               Year battle_number             attacker_king  \
# Battle of the Golden Tooth     298             1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford    298             2  Joffrey/Tommen Baratheon
# Battle of Riverrun             298             3  Joffrey/Tommen Baratheon
# Battle of the Green Fork       298             4                 Rob Stark
# Battle of the Whispering Wood  298             5                 Rob Stark
# Battle of the Camps            298             6                Robb Stark
# ERROR                          NaN           NaN                       NaN
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# ...

# %%
got.drop("ERROR", inplace=True)

# %%
got
# Out:
#                               Year battle_number             attacker_king  \
# Battle of the Golden Tooth     298             1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford    298             2  Joffrey/Tommen Baratheon
# Battle of Riverrun             298             3  Joffrey/Tommen Baratheon
# Battle of the Green Fork       298             4                 Rob Stark
# Battle of the Whispering Wood  298             5                 Rob Stark
# Battle of the Camps            298             6                Robb Stark
#
#                                           defender_king attacker_1 attacker_2  \
# Battle of the Golden Tooth                    Rob Stark  Lannister
# Battle at the Mummer's Ford                   Rob Stark  Lannister
# Battle of Riverrun                            Rob Stark  Lannister
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon      Stark      Tully
# ...
